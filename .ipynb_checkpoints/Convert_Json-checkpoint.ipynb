# %%
# Convert txt file into json, relationship is delineated by the number of whitespaces at the begining of the new line
import json

def parse_indented_file(filename):
    with open(filename, 'r') as f:
        lines = [line.rstrip('\n') for line in f if line.strip()]

    stack = []
    root = []

    for line in lines:
        indent = len(line) - len(line.lstrip(' '))
        node = {"name": line.strip(), "children": []}

        while stack and stack[-1][0] >= indent:
            stack.pop()

        if not stack:
            root.append(node)
        else:
            stack[-1][1]["children"].append(node)

        stack.append((indent, node))

    return root

if __name__ == "__main__":
    json_data = parse_indented_file("Phenotype_SNPs.txt")
    with open("Phenotype_SNPs.json", "w") as f:
        json.dump(json_data, f, indent=2)
    print("JSON saved to output.json")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 28
#      25     return root
#      27 if __name__ == "__main__":
# ---> 28     json_data = parse_indented_file("items.txt")
#      29     with open("output.json", "w") as f:
#      30         json.dump(json_data, f, indent=2)
#
# Cell In[1], line 5, in parse_indented_file(filename)
#       4 def parse_indented_file(filename):
# ----> 5     with open(filename, 'r') as f:
#       6         lines = [line.rstrip('\n') for line in f if line.strip()]
#       8     stack = []
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'items.txt'
